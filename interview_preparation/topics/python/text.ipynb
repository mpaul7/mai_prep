# %%
s = "Was it a car or a cat I saw?"

# %%
[c for c in s]
# Out:
# ['W',
#  'a',
#  's',
#  ' ',
#  'i',
#  't',
#  ' ',
#  'a',
#  ' ',
#  'c',
#  'a',
#  'r',
#  ' ',
#  'o',
#  'r',
#  ' ',
#  'a',
#  ' ',
#  'c',
#  'a',
#  't',
#  ' ',
#  'I',
#  ' ',
#  's',
#  'a',
#  'w',
#  '?']
